# %%
pip install selenium
# Out:
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
API_KEY = 'AIzaSyCQ6I7tNSf9RPDICpLrOMuoXhCnP9lUBn4'

# %%
html_code = f"""
<!DOCTYPE html>
<html>
  <head>
    <title>Google Maps API</title>
    <script src="https://maps.googleapis.com/maps/api/js?key={API_KEY}&callback=initMap" 
    async defer></script>
    <script>
      function initMap() {{
        var map = new google.maps.Map(document.getElementById('map'), {{
          center: {{lat: 23.79018824845412, lng: 90.40810815175121}},
          zoom: 20
        }});
      }}
    </script>
  </head>
  <body>
    <div id="map" style="height: 100vh;"></div>
  </body>
</html>
"""

# %%
with open("google_maps.html", "w") as file:
    file.write(html_code)

driver = webdriver.Chrome()
driver.get('C:\\Users\\Saleh Ahmed Shafin\\google_maps.html')

# %% [markdown]
# # **Explanation**

# %% [markdown]
# **Code Organization:**
# 1. Functions:
#
#     * Encapsulate different functionalities into functions to improve modularity and reusability.
#     * Create functions for generating HTML code, saving it to a file, and opening it in a browser.
# 2. Constants and Configurations:
#
#     * Place constants, such as the API key and file paths, at the beginning of your script for easy configuration.
# 3. Main Script:
#
#     * Use a main script or function to orchestrate the workflow, calling the necessary functions in a logical order.
# **Data Processing Approaches:**
# 1. HTML Code Generation:
#
#     * Utilize a template engine if the HTML code becomes more complex for better maintainability.
# 2. Configuration Management:
#
#     * Store configuration parameters in a separate configuration file or use command-line arguments for better configurability.
# 3. Error Handling:
#
#     * Implement robust error handling, especially for file operations, API requests, or browser automation, to gracefully handle exceptions.
# 4. Logging:
#
#     * Integrate logging to capture useful information during script execution, aiding in debugging and understanding the script's behavior.
